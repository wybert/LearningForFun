# %%
import geopandas as gpd
import  pymongo 
from pandas.io.json import json_normalize
from shapely.geometry import Point
### read dashangdi shapefile
def connectMongoDB(database,collection):
    conn_mongo = pymongo.MongoClient("localhost", 27017)
    db_mongo = conn_mongo[database]
    coll_mongo = db_mongo[collection]
    return coll_mongo

database='DaShangDi'
collection = 'shop_constrain'
DaShangDi_shop_constrain = connectMongoDB(database,collection)
#
#
#import sys  
#reload(sys)  
#sys.setdefaultencoding('utf8')
shop_constrain = json_normalize([item for item in DaShangDi_shop_constrain.find()])
test = shop_constrain.head()
# test

# %%
test.to_csv('test.csv',encoding='utf-8')

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

## 此行代码设置绘图style
plt.style.use('ggplot')

## 下面是常规的绘图命令
df1 = pd.read_csv('beautifulPlot/dataforexcies.csv')
df1 = df1[['a','b']][:5]
df1.plot(kind='bar',title='bar plot');

# %%
tips_data = pd.read_csv('tips.csv')

# %%
tips_data.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total_bill</th>
#       <th>tip</th>
#       <th>sex</th>
#       <th>smoker</th>
#       <th>day</th>
#       <th>time</th>
#       <th>size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.99</td>
#       <td>1.01</td>
#       <td>Female</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10.34</td>
#       <td>1.66</td>
#       <td>Male</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>21.01</td>
#       <td>3.50</td>
#       <td>Male</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>23.68</td>
#       <td>3.31</td>
#       <td>Male</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>24.59</td>
#       <td>3.61</td>
#       <td>Female</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import seaborn as sns
g = sns.FacetGrid(tips_data, row="sex", col="smoker")
g.map(plt.hist, "total_bill");

# %%
g = sns.FacetGrid(tips_data, row="sex", col="smoker")
g.map(sns.kdeplot, "total_bill");

# %%
g = sns.FacetGrid(tips_data, row="sex", col="smoker")
g.map(plt.scatter, "total_bill", "tip");
# Out:
# c:\users\wybert\anaconda2\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
g = sns.FacetGrid(tips_data, row="sex", col="smoker", margin_titles=True)
g.map(sns.regplot, "total_bill", "tip", order=2);

# %%
g = sns.FacetGrid(tips_data, row="sex", col="smoker")
g.map(plt.scatter, "total_bill", "tip")
g.map(sns.kdeplot, "total_bill", "tip")

# %%
g = sns.FacetGrid(tips_data, row="sex", col="smoker", hue="day")
g.map(plt.scatter, "tip", "total_bill")
g.add_legend()

# %%
df1.plot(kind='kde')

# %%
df1.values
# Out:
# array([[ 0.51955987,  0.09800075],
#        [ 0.61236068,  0.54905621],
#        [ 0.05279744,  0.58088577],
#        [ 0.44129831,  0.3538702 ],
#        [ 0.86400646,  0.1759225 ]])

# %%
from matplotlib import cm
fig, ax = plt.subplots()
cax = plt.imshow(df1.values,interpolation='nearest' ,cmap=cm.coolwarm);
cbar = fig.colorbar(cax, ticks=[ 0.05279744, 0.58088577, 0.86400646])
cbar.ax.set_yticklabels(['< -1', '0', '> 1'])  # vertically oriented colorbar
# Out:
# [<matplotlib.text.Text at 0x239e9278>,
#  <matplotlib.text.Text at 0x23b66198>,
#  <matplotlib.text.Text at 0x23be38d0>]

# %%
import matplotlib.pyplot as plt
import numpy as np

A = np.random.rand(5, 5)
plt.figure(1)
plt.imshow(A, interpolation='nearest')
# plt.grid(True)

plt.figure(2)
plt.imshow(A, interpolation='bilinear')
# plt.grid(True)

plt.figure(3)
plt.imshow(A, interpolation='bicubic')
# plt.grid(True)

plt.show()

# %%
from numpy.random import rand
Z = rand(6, 10)
c = plt.pcolor(Z)

# %%
plt.pcolor(df1.values,cmap=cm.coolwarm);
# plt.axis([x.min(), x.max(), y.min(), y.max()])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x0000000021E68308>

# %%
# sns.set(style="white")

sns.heatmap(df1.values,cmap=cm.coolwarm, annot=True);

# %%
from string import letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# sns.set(style="white")

# Generate a large random dataset
rs = np.random.RandomState(33)
d = pd.DataFrame(data=rs.normal(size=(100, 26)),
                 columns=list(letters[:26]))

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3,
            square=True, xticklabels=5, yticklabels=5,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

# %%
sns.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
sns.boxplot(data=data);
sns.despine(offset=10, trim=True)

# %%
cd C:\Users\wybert\Downloads\mplleaflet-master\examples
# Out:
# C:\Users\wybert\Downloads\mplleaflet-master\examples

# %%
# %load basic_plot.py
import json
import os

import matplotlib.pyplot as plt
import numpy as np

import mplleaflet

# Load up the geojson data
# filename = os.path.join(os.path.dirname(__file__), 'data', 'track.geojson')
with open('data/track.geojson') as f:
    gj = json.load(f)

# Grab the coordinates (longitude, latitude) from the features, which we
# know are Points
xy = np.array([feat['geometry']['coordinates'] for feat in gj['features'][::10]])

# Plot the path as red dots connected by a blue line
plt.hold(True)
# plt.plot(xy[:,0], xy[:,1], 'r.')
plt.plot(xy[:,0], xy[:,1], 'b')

# mapfile = 'test'  + '.html'
# Create the map. Save the file to basic_plot.html. _map.html is the default
# if 'path' is not specified
# mplleaflet.show(path=mapfile)
# mapfile = 'test'  + '.html'
mplleaflet.show()

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

ax = plt.axes(projection=ccrs.PlateCarree())
ax.stock_img()

ny_lon, ny_lat = -75, 43
delhi_lon, delhi_lat = 77.23, 28.61

plt.plot([ny_lon, delhi_lon], [ny_lat, delhi_lat],
         color='blue', linewidth=2, marker='o',
         transform=ccrs.Geodetic(),
         )

plt.plot([ny_lon, delhi_lon], [ny_lat, delhi_lat],
         color='gray', linestyle='--',
         transform=ccrs.PlateCarree(),
         )

plt.text(ny_lon - 3, ny_lat - 12, 'New York',
         horizontalalignment='right',
         transform=ccrs.Geodetic())

plt.text(delhi_lon + 3, delhi_lat - 12, 'Delhi',
         horizontalalignment='left',
         transform=ccrs.Geodetic())

plt.show()
# Out:
# c:\users\wybert\anaconda2\lib\site-packages\numpy\lib\shape_base.py:431: FutureWarning: in the future np.array_split will retain the shape of arrays with a zero size, instead of replacing them by `array([])`, which always has a shape of (0,).
#   FutureWarning)

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
plt.xkcd()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.stock_img()

ny_lon, ny_lat = -75, 43
delhi_lon, delhi_lat = 77.23, 28.61

plt.plot([ny_lon, delhi_lon], [ny_lat, delhi_lat],
         color='blue', linewidth=2, marker='o',
         transform=ccrs.Geodetic(),
         )

plt.plot([ny_lon, delhi_lon], [ny_lat, delhi_lat],
         color='gray', linestyle='--',
         transform=ccrs.PlateCarree(),
         )

plt.text(ny_lon - 3, ny_lat - 12, 'New York',
         horizontalalignment='right',
         transform=ccrs.Geodetic())

plt.text(delhi_lon + 3, delhi_lat - 12, 'Delhi',
         horizontalalignment='left',
         transform=ccrs.Geodetic())

plt.show()

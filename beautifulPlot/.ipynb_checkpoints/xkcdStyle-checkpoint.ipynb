# %% [markdown]
# # 简介

# %% [markdown]
# <a http://www.xkcd.com/>xkcd</a>是一个美国网络漫画家兰德尔·门罗创作的系列漫画,里面大致是类似这样的科学幽默漫画

# %% [markdown]
# <div align="center">
#     <img src="starlight_590.png" width="60%">
# </div>

# %% [markdown]
# 或者这样的漫画

# %% [markdown]
# <div align="center">
#     <img src="colds.png" width="40%">
# </div>

# %% [markdown]
# 我们可以使用matplotlib来绘制这种类型的图，下面是一个例子,来绘制一个心形（使用matplotlib绘图比较麻烦，可以使用pandas等同绘制这种类型的图表更加简单，可以直接看最后的使用pandas的例子）

# %%
"""
heart
"""
# %matplotlib inline
import matplotlib.path as mpath
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

## t下面这行会启动xkcd绘图
plt.xkcd()


fig, ax = plt.subplots()
Path = mpath.Path
path_data = [
    (Path.MOVETO, (1.58, -2.57)),
    (Path.CURVE4, (0.35, -1.1)),
    (Path.CURVE4, (-1.75, 2.0)),
    (Path.CURVE4, (0.375, 2.0)),
    (Path.LINETO, (0.85, 1.15)),
    (Path.CURVE4, (2.2, 3.2)),
    (Path.CURVE4, (3, 0.05)),
    (Path.CURVE4, (2.0, -0.5)),
    (Path.CLOSEPOLY, (1.58, -2.57)),
    ]
codes, verts = zip(*path_data)
path = mpath.Path(verts, codes)
patch = mpatches.PathPatch(path, facecolor='r', alpha=0.5)
ax.add_patch(patch)

# plot control points and connecting lines
x, y = zip(*path.vertices)
line, = ax.plot(x, y, 'go-')

ax.grid()
ax.axis('equal')
plt.show()

# %% [markdown]
# 下面的例子来绘制折线图和柱状图

# %%
from matplotlib import pyplot as plt
import numpy as np

plt.xkcd()

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.xticks([])
plt.yticks([])
ax.set_ylim([-30, 10])

data = np.ones(100)
data[70:] -= np.arange(30)

plt.annotate(
    'THE DAY I REALIZED\nI COULD COOK BACON\nWHENEVER I WANTED',
    xy=(70, 1), arrowprops=dict(arrowstyle='->'), xytext=(15, -10))

plt.plot(data)

plt.xlabel('time')
plt.ylabel('my overall health')

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.bar([-0.125, 1.0-0.125], [0, 100], 0.25)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.set_xticks([0, 1])
ax.set_xlim([-0.5, 1.5])
ax.set_ylim([0, 110])
ax.set_xticklabels(['CONFIRMED BY\nEXPERIMENT', 'REFUTED BY\nEXPERIMENT'])
plt.yticks([])

plt.title("CLAIMS OF SUPERNATURAL POWERS")

plt.show()

# %% [markdown]
# 下面的例子使用pandas结合matplotlib来绘制柱形图，折线图

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

## 下面这行代码来启动xkcd绘图
plt.xkcd()

## 下面是常规的绘图命令
df1 = pd.read_csv('dataforexcies.csv')
df1 = df1[['a','b']][:5]
df1.plot(kind='bar',title='bar plot');
df1.plot(kind='line',title='line plot');
